# %%
import pandas as pd
import numpy as np

# %%
n_cols = 50
n_rows = 50

df = pd.DataFrame(np.random.rand(50, 50), columns=['column_'+str(i) for i in range(1, 51)])

# %%
df
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6  column_7  \
# 0   0.535672  0.967072  0.127460  0.443658  0.217957  0.605604  0.066479
# 1   0.508609  0.916418  0.073103  0.961565  0.434582  0.177224  0.291358
# 2   0.050997  0.343874  0.561179  0.558215  0.171790  0.377476  0.704779
# 3   0.323329  0.891358  0.173107  0.752906  0.930019  0.484742  0.110902
# 4   0.175329  0.617955  0.989878  0.163055  0.068762  0.887408  0.315329
# 5   0.826619  0.098116  0.823198  0.463613  0.294534  0.032868  0.664979
# 6   0.410926  0.736285  0.619285  0.379077  0.409711  0.929022  0.183353
# 7   0.084303  0.479860  0.876419  0.471355  0.647421  0.709196  0.392604
# 8   0.006947  0.358890  0.145661  0.492546  0.107136  0.896620  0.259247
# 9   0.589426  0.530343  0.703286  0.585353  0.381630  0.905343  0.697893
# 10  0.319170  0.594897  0.876784  0.551923  0.512960  0.394999  0.563344
# 11  0.930957  0.923958  0.002129  0.980733  0.263075  0.853196  0.692445
# ...

# %%
pd.DataFrame([[1, 2], [3, 4]], columns=['column_1', 'column_2'])
# Out:
#    column_1  column_2
# 0         1         2
# 1         3         4
